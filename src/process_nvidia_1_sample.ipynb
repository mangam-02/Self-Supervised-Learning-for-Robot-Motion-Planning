# %%
# ---------- Setup ----------
# %load_ext autoreload
# %autoreload 2
import sys, os
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# Verify that SimpleArm is in the path
SIMPLEARM_PATH = os.path.abspath("../external/SimpleArm/src")
if SIMPLEARM_PATH not in sys.path:
    sys.path.insert(0, SIMPLEARM_PATH)

from simplearm.robot import RobotInfo

# Import local functions
import models
from data import generate_dataset, print_dataset_stats, browse_dataset, visualize_environment
from losses import compute_trajectory_collision_cost, compute_trajectory_joint_limits_cost
from utils import get_world_spheres_torch, query_sdf_differentiable
from training import train, train_env_autoencoder, train_state_autoencoder
from visualization import browse_trajectories

# Robot configuration
WORKSPACE_RADIUS = 1.0
LINK_LENGTHS = [0.35, 0.45, 0.2]
SPHERE_RAD = 0.08
GRID_LENGTH = 2.5
N_VOX = 128
T = 50  # Time steps in the trajectory
C = 10  # Control points in the spline
Q_MIN = np.array([-np.pi*0.9, -np.pi*0.9, -np.pi*0.9])
Q_MAX = np.array([np.pi*0.9, np.pi*0.9, np.pi*0.9])

robot = RobotInfo.from_linklengths(LINK_LENGTHS, sphere_rad=SPHERE_RAD)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    gpu_name = torch.cuda.get_device_name(0)
    print(f"Setup done. Executed in GPU: {gpu_name}")
else:
    print("Setup done. WARNING: Running on CPU. GPU not detected.")
# Out:
# Setup done. Executed in GPU: Tesla T4

# %%
# ---------- SDF Dataset ----------
from data import generate_sdf_dataset

# Generate 20,000 environments for training the Autoencoder 
print("Generating SDFs...")
sdf_dataset = generate_sdf_dataset(N=20000, save_path="data/sdf_dataset_0807.pt", seed=42)

# Visual control
idx = torch.randint(0, len(sdf_dataset), (1,)).item()
plt.figure(figsize=(4, 4))
plt.imshow(sdf_dataset[idx, 0].cpu().numpy(), cmap="jet_r", origin="lower", 
           extent=[-GRID_LENGTH/2, GRID_LENGTH/2, -GRID_LENGTH/2, GRID_LENGTH/2])
plt.title(f"Control SDF (Index {idx})")
plt.colorbar(label="Distance to the obstacle")
plt.show()
# Out:
# Generating SDFs...
# Generating SDF dataset:   0%|          | 0/20000 [00:00<?, ?it/s]
# SDF dataset saved: data/sdf_dataset_0807.pt  shape=(20000, 1, 128, 128)

# %%
# ---------- Environment Autoencoder Training ----------
print("Training the Environment Autoencoder...")

env_model, env_history = train_env_autoencoder(
    dataset_path = "data/sdf_dataset_0807.pt",
    file_name = "env_encoder_0807.pt",
    latent_dim   = 64,
    batch_size   = 128,                           
    epochs       = 8000,                          
    lr           = 1e-3,
    log_every    = 100,
    device       = device,
    save_path    = "data/env_autoencoder_0807.pt" 
)

print("Weights saved in 'data/env_autoencoder_0807.pt'")
# Out:
# Training the Environment Autoencoder...
# Training Env Autoencoder:   0%|          | 0/8000 [00:00<?, ?it/s]
# Test loss: 0.000160
# Saved: data/env_autoencoder_0807.pt  (encoder -> data/env_encoder_0807.pt)
# Weights saved in 'data/env_autoencoder_0807.pt'

# %%
# ---------- State Autoencoder Training ----------
from training import train_state_autoencoder
state_ae, state_ae_history = train_state_autoencoder(
    file_name   = "state_encoder_0807.pt",
    linklengths = LINK_LENGTHS,
    dof         = 3,
    latent_dim  = 12,
    N           = 240_000,
    batch_size  = 256,
    epochs      = 8000,
    lr          = 1e-3,
    log_every   = 100,
    device      = device,
    save_path   = "data/state_autoencoder_0807.pt"
)

print("Weights saved in 'data/state_autoencoder_0807.pt'")
# Out:
# Training State Autoencoder:   0%|          | 0/8000 [00:00<?, ?it/s]
# Test loss: 0.004188
# Saved: data/state_autoencoder_0807.pt  (encoder -> data/state_encoder_0807.pt)
# Weights saved in 'data/state_autoencoder_0807.pt'

# %%
# ---------- Dataset generation ----------
SEED = 42

# General Dataset
dataset_general_0807 = generate_dataset(
        N_envs            = 1000,
        pairs_per_env     = 10,
        robot             = robot,
        sphere_rad        = SPHERE_RAD,
        q_min             = Q_MIN,
        q_max             = Q_MAX,
        n_obstacles_range = (1, 3),
        r_range           = (0.06, 0.18),
        workspace_radius  = WORKSPACE_RADIUS,
        dist_from_origin  = (0.61, WORKSPACE_RADIUS),
        require_nontrivial= True,
        grid_length       = GRID_LENGTH,
        n_vox             = N_VOX,
        seed              = SEED,
        save_path         = "data/dataset_general_0807.pt",
        split             = (0.7, 0.15, 0.15)
        )
# Out:
# Generating dataset:   0%|          | 0/1000 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           10000
#   No valid pair:      2
#   Successful samples: 9998  (100.0%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_general_0807_train.pt  (6998 samples, 459.1 MB)
#   Saved: data/dataset_general_0807_val.pt  (1499 samples, 98.3 MB)
#   Saved: data/dataset_general_0807_test.pt  (1501 samples, 98.5 MB)

# %%
# ---------- Datasets analysis ----------
print("=== DATASETS - GENERAL STATISTICS ===")

print("\n1. General Dataset:")
print_dataset_stats("data/dataset_general_0807_train.pt")

print("\n" + "="*20 + " INTERACTIVE VISUALIZATION " + "="*20 + "\n")
interactive_dataset = torch.load("data/dataset_general_0807_train.pt", weights_only=False)
browse_dataset(interactive_dataset, grid_length=GRID_LENGTH)
# Out:
# === DATASETS - GENERAL STATISTICS ===
#
# 1. General Dataset:
# Dataset: 6998 samples
#   sdf          (6998, 1, 128, 128)
#   q_start      (6998, 3)
#   q_goal       (6998, 3)
#   obstacles    (6998, 3, 3)
#   n_obstacles  (6998,)
#
# Metadata: {'N': 6998, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [np.float64(0.35), np.float64(0.45), np.float64(0.2)], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 100 samples): mean=0.000  (should be ~0.0)
#
# ==================== INTERACTIVE VISUALIZATION ====================
# VBox(children=(HBox(children=(Button(description='◄ Prev', layout=Layout(width='100px'), style=ButtonStyle()),…

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset - 08/07
print("Starting training...")
    
model_general_0807_v1, history_general_0807_v1 = train(
    # Paths
    train_dataset       = "data/dataset_general_0807_train.pt",
    val_dataset         = "data/dataset_general_0807_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_0807.pt",
    state_encoder_path  = "data/state_encoder_0807.pt",
    freeze_encoders     = True,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 128,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 100.0,
    w_joints            = 1.0,
    w_smooth            = 2.0,
    w_spacing           = 2.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.10,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/wsp_general_0807_v1.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_0807.pt
# Loaded state encoder: data/state_encoder_0807.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           2.3763    100.0000    237.6335
# joints         0.0000      1.0000      0.0000
# smooth         0.2016      2.0000      0.4031
# spacing        0.0000      2.0000      0.0000
# explore        0.3164      5.0000      1.5820
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.97e-04 | train=7.7886  coll=6.9013  joints=0.1655  smooth=0.6733  spacing=0.0485  explore=0.0000  val=8.3395
# Epoch   400 | lr=4.88e-04 | train=6.6925  coll=5.0667  joints=0.1531  smooth=1.3540  spacing=0.1187  explore=0.0000  val=6.2322
# Epoch   600 | lr=4.73e-04 | train=4.8460  coll=2.8683  joints=0.0210  smooth=1.8456  spacing=0.1111  explore=0.0000  val=4.2110
# Epoch   800 | lr=4.52e-04 | train=3.8567  coll=2.0781  joints=0.0070  smooth=1.6818  spacing=0.0844  explore=0.0055  val=3.9016
# Epoch  1000 | lr=4.27e-04 | train=3.5056  coll=1.6676  joints=0.0243  smooth=1.7345  spacing=0.0791  explore=0.0000  val=3.8939
# Epoch  1200 | lr=3.97e-04 | train=3.6624  coll=1.8312  joints=0.0060  smooth=1.7299  spacing=0.0946  explore=0.0007  val=3.7933
# Epoch  1400 | lr=3.64e-04 | train=3.0167  coll=1.2412  joints=0.0090  smooth=1.6759  spacing=0.0906  explore=0.0000  val=3.7100
# Epoch  1600 | lr=3.28e-04 | train=3.2635  coll=1.5694  joints=0.0052  smooth=1.6005  spacing=0.0884  explore=0.0000  val=3.6783
# Epoch  1800 | lr=2.90e-04 | train=3.5571  coll=1.8553  joints=0.0222  smooth=1.5892  spacing=0.0904  explore=0.0000  val=3.6709
# Epoch  2000 | lr=2.50e-04 | train=3.3247  coll=1.5962  joints=0.0000  smooth=1.6519  spacing=0.0767  explore=0.0000  val=3.6798
# Epoch  2200 | lr=2.11e-04 | train=3.1944  coll=1.3696  joints=0.0000  smooth=1.7186  spacing=0.1062  explore=0.0000  val=3.6203
# Epoch  2400 | lr=1.73e-04 | train=3.0162  coll=1.3369  joints=0.0175  smooth=1.5713  spacing=0.0906  explore=0.0000  val=3.6088
# Epoch  2600 | lr=1.37e-04 | train=3.0982  coll=1.3363  joints=0.0002  smooth=1.6739  spacing=0.0879  explore=0.0000  val=3.6025
# Epoch  2800 | lr=1.04e-04 | train=2.9087  coll=1.2349  joints=0.0003  smooth=1.5833  spacing=0.0902  explore=0.0000  val=3.5722
# Epoch  3000 | lr=7.41e-05 | train=3.2877  coll=1.4827  joints=0.0000  smooth=1.7121  spacing=0.0929  explore=0.0000  val=3.5872
# Epoch  3200 | lr=4.87e-05 | train=3.1110  coll=1.3724  joints=0.0010  smooth=1.6511  spacing=0.0866  explore=0.0000  val=3.5650
# Epoch  3400 | lr=2.82e-05 | train=2.6109  coll=1.0129  joints=0.0000  smooth=1.5071  spacing=0.0910  explore=0.0000  val=3.5623
# Epoch  3600 | lr=1.32e-05 | train=2.7605  coll=1.2413  joints=0.0000  smooth=1.4464  spacing=0.0728  explore=0.0000  val=3.5715
# Epoch  3800 | lr=4.07e-06 | train=2.8974  coll=1.1629  joints=0.0001  smooth=1.6424  spacing=0.0919  explore=0.0000  val=3.5677
# Epoch  4000 | lr=1.00e-06 | train=2.9533  coll=1.2176  joints=0.0007  smooth=1.6564  spacing=0.0787  explore=0.0000  val=3.5692
# Model saved: models/wsp_general_0807_v1.pt

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset - 09/07
print("Starting training...")
    
model_general_0907_v1, history_general_0907_v1 = train(
    # Paths
    train_dataset       = "data/dataset_general_0807_train.pt",
    val_dataset         = "data/dataset_general_0807_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_0807.pt",
    state_encoder_path  = "data/state_encoder_0807.pt",
    freeze_encoders     = True,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 128,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 350.0,
    w_joints            = 1.0,
    w_smooth            = 1.0,
    w_spacing           = 2.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.15,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/wsp_general_0907_v1.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_0807.pt
# Loaded state encoder: data/state_encoder_0807.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           3.7849    350.0000   1324.7005
# joints         0.0000      1.0000      0.0000
# smooth         0.2016      1.0000      0.2016
# spacing        0.0000      2.0000      0.0000
# explore        0.3164      5.0000      1.5820
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.97e-04 | train=28.0341  coll=25.4087  joints=1.5528  smooth=0.8127  spacing=0.2599  explore=0.0000  val=29.1824
# Epoch   400 | lr=4.88e-04 | train=14.4568  coll=12.9225  joints=0.0803  smooth=1.2215  spacing=0.2325  explore=0.0000  val=14.5581
# Epoch   600 | lr=4.73e-04 | train=12.1863  coll=10.6985  joints=0.0381  smooth=1.2949  spacing=0.1549  explore=0.0000  val=12.7703
# Epoch   800 | lr=4.52e-04 | train=10.8748  coll=9.5584  joints=0.0263  smooth=1.1681  spacing=0.1219  explore=0.0000  val=11.8331
# Epoch  1000 | lr=4.27e-04 | train=9.2003  coll=7.9514  joints=0.0244  smooth=1.0821  spacing=0.1424  explore=0.0000  val=11.3373
# Epoch  1200 | lr=3.97e-04 | train=9.9999  coll=8.6268  joints=0.0055  smooth=1.2285  spacing=0.1390  explore=0.0000  val=11.4592
# Epoch  1400 | lr=3.64e-04 | train=9.3775  coll=8.0719  joints=0.0016  smooth=1.1589  spacing=0.1452  explore=0.0000  val=11.7877
# Epoch  1600 | lr=3.28e-04 | train=9.3923  coll=8.0907  joints=0.0020  smooth=1.1506  spacing=0.1490  explore=0.0000  val=11.2233
# Epoch  1800 | lr=2.90e-04 | train=9.5919  coll=8.3918  joints=0.0002  smooth=1.0492  spacing=0.1508  explore=0.0000  val=11.2257
# Epoch  2000 | lr=2.50e-04 | train=9.7317  coll=8.4555  joints=0.0110  smooth=1.1226  spacing=0.1425  explore=0.0000  val=11.3339
# Epoch  2200 | lr=2.11e-04 | train=8.8395  coll=7.5419  joints=0.0051  smooth=1.1389  spacing=0.1537  explore=0.0000  val=11.0798
# Epoch  2400 | lr=1.73e-04 | train=9.2780  coll=7.9791  joints=0.0041  smooth=1.1578  spacing=0.1370  explore=0.0000  val=10.9731
# Epoch  2600 | lr=1.37e-04 | train=9.7061  coll=8.4405  joints=0.0034  smooth=1.1089  spacing=0.1532  explore=0.0000  val=11.0429
# Epoch  2800 | lr=1.04e-04 | train=9.1380  coll=7.8979  joints=0.0001  smooth=1.0870  spacing=0.1530  explore=0.0000  val=11.0501
# Epoch  3000 | lr=7.41e-05 | train=8.5860  coll=7.3258  joints=0.0043  smooth=1.1054  spacing=0.1505  explore=0.0000  val=10.9400
# Epoch  3200 | lr=4.87e-05 | train=8.7006  coll=7.4261  joints=0.0012  smooth=1.1203  spacing=0.1530  explore=0.0000  val=10.9570
# Epoch  3400 | lr=2.82e-05 | train=8.7491  coll=7.5274  joints=0.0039  smooth=1.0744  spacing=0.1434  explore=0.0000  val=10.9619
# Epoch  3600 | lr=1.32e-05 | train=8.2378  coll=7.0495  joints=0.0011  smooth=1.0373  spacing=0.1499  explore=0.0000  val=10.9470
# Epoch  3800 | lr=4.07e-06 | train=8.5718  coll=7.3239  joints=0.0031  smooth=1.0748  spacing=0.1700  explore=0.0000  val=10.9435
# Epoch  4000 | lr=1.00e-06 | train=8.0170  coll=6.7501  joints=0.0000  smooth=1.1175  spacing=0.1494  explore=0.0000  val=10.9498
# Model saved: models/wsp_general_0907_v1.pt

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset - 09/07
print("Starting training...")
    
model_general_0907_v2, history_general_0907_v2 = train(
    # Paths
    train_dataset       = "data/dataset_general_0807_train.pt",
    val_dataset         = "data/dataset_general_0807_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_0807.pt",
    state_encoder_path  = "data/state_encoder_0807.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 128,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 350.0,
    w_joints            = 1.0,
    w_smooth            = 1.0,
    w_spacing           = 2.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.15,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/wsp_general_0907_v2.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_0807.pt
# Loaded state encoder: data/state_encoder_0807.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           3.7849    350.0000   1324.7005
# joints         0.0000      1.0000      0.0000
# smooth         0.2016      1.0000      0.2016
# spacing        0.0000      2.0000      0.0000
# explore        0.3164      5.0000      1.5820
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.97e-04 | train=20.5502  coll=18.4022  joints=0.3964  smooth=1.3038  spacing=0.4479  explore=0.0000  val=21.0524
# Epoch   400 | lr=4.88e-04 | train=12.5230  coll=11.1373  joints=0.0596  smooth=1.1497  spacing=0.1753  explore=0.0011  val=12.8494
# Epoch   600 | lr=4.73e-04 | train=12.1113  coll=10.7950  joints=0.0003  smooth=1.1515  spacing=0.1644  explore=0.0000  val=11.5041
# Epoch   800 | lr=4.52e-04 | train=11.3861  coll=10.0681  joints=0.0179  smooth=1.1303  spacing=0.1698  explore=0.0000  val=11.7005
# Epoch  1000 | lr=4.27e-04 | train=12.3017  coll=11.0885  joints=0.0041  smooth=1.0596  spacing=0.1495  explore=0.0000  val=11.1809
# Epoch  1200 | lr=3.97e-04 | train=9.5487  coll=8.3649  joints=0.0027  smooth=1.0407  spacing=0.1403  explore=0.0000  val=11.1699
# Epoch  1400 | lr=3.64e-04 | train=9.5400  coll=8.3608  joints=0.0053  smooth=1.0270  spacing=0.1469  explore=0.0000  val=10.7611
# Epoch  1600 | lr=3.28e-04 | train=8.0868  coll=6.9143  joints=0.0171  smooth=1.0160  spacing=0.1394  explore=0.0000  val=10.9013
# Epoch  1800 | lr=2.90e-04 | train=9.3009  coll=8.1076  joints=0.0103  smooth=1.0482  spacing=0.1348  explore=0.0000  val=10.9360
# Epoch  2000 | lr=2.50e-04 | train=10.0137  coll=8.7408  joints=0.0026  smooth=1.1337  spacing=0.1367  explore=0.0000  val=10.8131
# Epoch  2200 | lr=2.11e-04 | train=8.2678  coll=7.0465  joints=0.0059  smooth=1.0784  spacing=0.1370  explore=0.0000  val=10.7944
# Epoch  2400 | lr=1.73e-04 | train=9.1627  coll=7.9323  joints=0.0084  smooth=1.0991  spacing=0.1229  explore=0.0000  val=10.6264
# Epoch  2600 | lr=1.37e-04 | train=8.1820  coll=7.0792  joints=0.0042  smooth=0.9755  spacing=0.1231  explore=0.0000  val=10.7621
# Epoch  2800 | lr=1.04e-04 | train=7.6438  coll=6.5859  joints=0.0006  smooth=0.9482  spacing=0.1091  explore=0.0000  val=10.6982
# Epoch  3000 | lr=7.41e-05 | train=7.4139  coll=6.3094  joints=0.0001  smooth=0.9857  spacing=0.1188  explore=0.0000  val=10.7087
# Epoch  3200 | lr=4.87e-05 | train=8.1327  coll=7.0213  joints=0.0002  smooth=0.9794  spacing=0.1318  explore=0.0000  val=10.8189
# Epoch  3400 | lr=2.82e-05 | train=7.3863  coll=6.3095  joints=0.0000  smooth=0.9437  spacing=0.1332  explore=0.0000  val=10.7530
# Epoch  3600 | lr=1.32e-05 | train=7.6790  coll=6.5818  joints=0.0004  smooth=0.9730  spacing=0.1238  explore=0.0000  val=10.7712
# Epoch  3800 | lr=4.07e-06 | train=8.3945  coll=7.2840  joints=0.0114  smooth=0.9796  spacing=0.1196  explore=0.0000  val=10.7828
# Epoch  4000 | lr=1.00e-06 | train=7.5131  coll=6.4616  joints=0.0012  smooth=0.9357  spacing=0.1146  explore=0.0000  val=10.7834
# Model saved: models/wsp_general_0907_v2.pt

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset
print("Starting training...")
    
model_general_v4, history_general_v4 = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_general_train.pt",
    val_dataset         = "data/dataset_overfit_v2_general_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_general_v1.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 128,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_general_v4.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_general_v1.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           7.5295   1500.0000  11294.3223
# joints         0.0000      5.0000      0.0000
# smooth         0.2750      2.0000      0.5500
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=156.8297  coll=146.0420  joints=5.9919  smooth=4.4244  spacing=0.3714  explore=0.0000  val=202.8777
# Epoch   400 | lr=4.09e-04 | train=102.1715  coll=98.1470  joints=0.2377  smooth=3.5224  spacing=0.2644  explore=0.0000  val=104.9751
# Epoch   600 | lr=3.70e-04 | train=103.2282  coll=99.4471  joints=0.2793  smooth=3.2810  spacing=0.2209  explore=0.0000  val=105.9064
# Epoch   800 | lr=3.35e-04 | train=96.6117  coll=92.9680  joints=0.3147  smooth=3.1618  spacing=0.1673  explore=0.0000  val=98.5772
# Epoch  1000 | lr=3.03e-04 | train=90.6357  coll=87.5191  joints=0.1195  smooth=2.8506  spacing=0.1464  explore=0.0000  val=101.3355
# Epoch  1200 | lr=2.74e-04 | train=92.9593  coll=89.3910  joints=0.2424  smooth=3.1707  spacing=0.1553  explore=0.0000  val=101.1555
# Epoch  1400 | lr=2.48e-04 | train=86.1535  coll=82.3991  joints=0.2351  smooth=3.3566  spacing=0.1627  explore=0.0000  val=99.0374
# Epoch  1600 | lr=2.25e-04 | train=92.6843  coll=89.1184  joints=0.1270  smooth=3.2854  spacing=0.1535  explore=0.0000  val=98.3264
# Epoch  1800 | lr=2.03e-04 | train=97.2449  coll=93.8447  joints=0.1051  smooth=3.1506  spacing=0.1444  explore=0.0000  val=99.5960
# Epoch  2000 | lr=1.84e-04 | train=79.2255  coll=75.7399  joints=0.1073  smooth=3.2482  spacing=0.1301  explore=0.0000  val=98.6769
# Epoch  2200 | lr=1.66e-04 | train=87.6115  coll=84.1705  joints=0.1046  smooth=3.2033  spacing=0.1332  explore=0.0000  val=97.8941
# Epoch  2400 | lr=1.51e-04 | train=91.1680  coll=87.9920  joints=0.0195  smooth=3.0249  spacing=0.1316  explore=0.0000  val=97.7296
# Epoch  2600 | lr=1.36e-04 | train=78.9294  coll=75.6788  joints=0.0626  smooth=3.0695  spacing=0.1185  explore=0.0000  val=96.6890
# Epoch  2800 | lr=1.23e-04 | train=76.9581  coll=73.5453  joints=0.0424  smooth=3.2310  spacing=0.1394  explore=0.0000  val=97.4725
# Epoch  3000 | lr=1.12e-04 | train=90.8879  coll=87.5293  joints=0.0619  smooth=3.1736  spacing=0.1231  explore=0.0000  val=97.0336
# Epoch  3200 | lr=1.01e-04 | train=80.6877  coll=77.2045  joints=0.0718  smooth=3.2740  spacing=0.1374  explore=0.0000  val=97.6375
# Epoch  3400 | lr=9.13e-05 | train=85.8851  coll=82.5043  joints=0.0024  smooth=3.2519  spacing=0.1264  explore=0.0000  val=97.2819
# Epoch  3600 | lr=8.26e-05 | train=77.3626  coll=74.2428  joints=0.0373  smooth=2.9638  spacing=0.1186  explore=0.0000  val=96.6360
# Epoch  3800 | lr=7.47e-05 | train=82.8473  coll=79.6583  joints=0.0024  smooth=3.0653  spacing=0.1213  explore=0.0000  val=96.8345
# Epoch  4000 | lr=6.76e-05 | train=73.3492  coll=70.1180  joints=0.0047  smooth=3.1103  spacing=0.1162  explore=0.0000  val=96.8309
# Model saved: models/warm_start_planner_general_v4.pt

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset
print("Starting training...")
    
model_general_v2, history_general_v2 = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_general_train.pt",
    val_dataset         = "data/dataset_overfit_v2_general_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_overfit_v2.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 256,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_general_v2.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_overfit_v2.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll          14.7539   1500.0000  22130.8022
# joints         0.0000      5.0000      0.0000
# smooth         0.2816      2.0000      0.5632
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=178.3258  coll=172.5755  joints=1.4609  smooth=4.0302  spacing=0.2438  explore=0.0154  val=180.7327
# Epoch   400 | lr=4.09e-04 | train=115.3756  coll=110.2159  joints=1.2775  smooth=3.6337  spacing=0.2485  explore=0.0000  val=113.3982
# Epoch   600 | lr=3.70e-04 | train=104.9051  coll=100.8909  joints=0.2982  smooth=3.5002  spacing=0.2158  explore=0.0000  val=98.8827
# Epoch   800 | lr=3.35e-04 | train=95.5725  coll=91.8111  joints=0.0143  smooth=3.5393  spacing=0.2078  explore=0.0000  val=94.4493
# Epoch  1000 | lr=3.03e-04 | train=96.2324  coll=92.3820  joints=0.0294  smooth=3.6098  spacing=0.2112  explore=0.0000  val=93.4150
# Epoch  1200 | lr=2.74e-04 | train=97.8107  coll=94.3036  joints=0.0179  smooth=3.3076  spacing=0.1816  explore=0.0000  val=94.5574
# Epoch  1400 | lr=2.48e-04 | train=93.8781  coll=90.2121  joints=0.0056  smooth=3.4740  spacing=0.1865  explore=0.0000  val=91.9222
# Epoch  1600 | lr=2.25e-04 | train=92.2862  coll=88.5205  joints=0.0069  smooth=3.5746  spacing=0.1842  explore=0.0000  val=91.3511
# Epoch  1800 | lr=2.03e-04 | train=92.0865  coll=88.3160  joints=0.0029  smooth=3.5902  spacing=0.1773  explore=0.0000  val=92.0052
# Epoch  2000 | lr=1.84e-04 | train=93.0875  coll=89.4360  joints=0.0127  smooth=3.4780  spacing=0.1607  explore=0.0000  val=91.6957
# Epoch  2200 | lr=1.66e-04 | train=90.2081  coll=86.5672  joints=0.0168  smooth=3.4594  spacing=0.1647  explore=0.0000  val=91.1123
# Epoch  2400 | lr=1.51e-04 | train=86.0897  coll=82.6033  joints=0.0086  smooth=3.3364  spacing=0.1414  explore=0.0000  val=91.1378
# Epoch  2600 | lr=1.36e-04 | train=96.4642  coll=92.6031  joints=0.0549  smooth=3.6500  spacing=0.1562  explore=0.0000  val=91.0358
# Epoch  2800 | lr=1.23e-04 | train=90.4582  coll=86.8509  joints=0.0472  smooth=3.4107  spacing=0.1494  explore=0.0000  val=90.4451
# Epoch  3000 | lr=1.12e-04 | train=85.4354  coll=81.8248  joints=0.0220  smooth=3.4460  spacing=0.1426  explore=0.0000  val=90.5074
# Epoch  3200 | lr=1.01e-04 | train=93.0342  coll=89.4657  joints=0.0101  smooth=3.4130  spacing=0.1453  explore=0.0000  val=90.6928
# Epoch  3400 | lr=9.13e-05 | train=90.8788  coll=87.3115  joints=0.0161  smooth=3.4033  spacing=0.1479  explore=0.0000  val=90.5948
# Epoch  3600 | lr=8.26e-05 | train=85.4765  coll=81.8952  joints=0.0314  smooth=3.3930  spacing=0.1569  explore=0.0000  val=90.5017
# Epoch  3800 | lr=7.47e-05 | train=91.8708  coll=88.3747  joints=0.0003  smooth=3.3523  spacing=0.1434  explore=0.0000  val=90.4706
# Epoch  4000 | lr=6.76e-05 | train=83.0206  coll=79.6440  joints=0.0030  smooth=3.2326  spacing=0.1410  explore=0.0000  val=90.3835
# Model saved: models/warm_start_planner_general_v2.pt

# %%
# ---------- Trajectory Visualization ----------
print("Loading model and dataset...")

# Load the model
model_general = torch.load("models/wsp_general_0907_v1.pt", weights_only=False)
    
# Launch the visualizator
browse_trajectories(
    model     = model_general,
    dataset   = "data/dataset_general_0807_test.pt",
    save_name = "wsp_working_0907_v1"
)
# Out:
# Loading model and dataset...
# VBox(children=(HTML(value="<div style='background-color: #f8f9fa; padding: 14px; border-radius: 8px; border-le…
