# %%
# ---------- Setup ----------
# %load_ext autoreload
# %autoreload 2
import sys, os
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# Verify that SimpleArm is in the path
SIMPLEARM_PATH = os.path.abspath("../external/SimpleArm/src")
if SIMPLEARM_PATH not in sys.path:
    sys.path.insert(0, SIMPLEARM_PATH)

from simplearm.robot import RobotInfo

# Import local functions
import models
from data import generate_dataset, print_dataset_stats, browse_dataset, visualize_environment
from losses import compute_trajectory_collision_cost, compute_trajectory_joint_limits_cost
from utils import get_world_spheres_torch, query_sdf_differentiable
from training import train, train_env_autoencoder, train_state_autoencoder
from visualization import browse_trajectories

# Robot configuration
WORKSPACE_RADIUS = 1.0
LINK_LENGTHS = [0.35, 0.45, 0.2]
SPHERE_RAD = 0.08
GRID_LENGTH = 2.5
N_VOX = 128
T = 50  # Time steps in the trajectory
C = 10  # Control points in the spline
Q_MIN = np.array([-np.pi*0.9, -np.pi*0.9, -np.pi*0.9])
Q_MAX = np.array([np.pi*0.9, np.pi*0.9, np.pi*0.9])

robot = RobotInfo.from_linklengths(LINK_LENGTHS, sphere_rad=SPHERE_RAD)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    gpu_name = torch.cuda.get_device_name(0)
    print(f"Setup done. Executed in GPU: {gpu_name}")
else:
    print("Setup done. WARNING: Running on CPU. GPU not detected.")
# Out:
# Setup done. Executed in GPU: Tesla T4

# %%
# ---------- SDF Dataset ----------
from data import generate_sdf_dataset

# Generate 20,000 environments for training the Autoencoder 
print("Generating SDFs...")
sdf_dataset = generate_sdf_dataset(N=20000, save_path="data/sdf_dataset_overfit_v2.pt", seed=42)

# Visual control
idx = torch.randint(0, len(sdf_dataset), (1,)).item()
plt.figure(figsize=(4, 4))
plt.imshow(sdf_dataset[idx, 0].cpu().numpy(), cmap="jet_r", origin="lower", 
           extent=[-GRID_LENGTH/2, GRID_LENGTH/2, -GRID_LENGTH/2, GRID_LENGTH/2])
plt.title(f"Control SDF (Index {idx})")
plt.colorbar(label="Distance to the obstacle")
plt.show()
# Out:
# Generating SDFs...
# Generating SDF dataset:   0%|          | 0/20000 [00:00<?, ?it/s]
# SDF dataset saved: data/sdf_dataset_overfit_v2.pt  shape=(20000, 1, 128, 128)

# %%
# ---------- Environment Autoencoder Training ----------
print("Training the Environment Autoencoder...")

env_model, env_history = train_env_autoencoder(
    dataset_path = "data/sdf_dataset_overfit_v2.pt",
    file_name = "env_encoder_overfit_v2.pt",
    latent_dim   = 64,
    batch_size   = 128,                           
    epochs       = 8000,                          
    lr           = 1e-3,
    log_every    = 100,
    device       = device,
    save_path    = "data/env_autoencoder_overfit_v2.pt" 
)

print("Weights saved in 'data/env_autoencoder_overfit_v2.pt'")
# Out:
# Training the Environment Autoencoder...
# Training Env Autoencoder:   0%|          | 0/8000 [00:00<?, ?it/s]
# Test loss: 0.001617
# Saved: data/env_autoencoder_overfit_v2.pt  (encoder -> data\env_encoder_overfit_v2.pt)
# Weights saved in 'data/env_autoencoder_overfit_v2.pt'

# %%
# ---------- State Autoencoder Training ----------
from training import train_state_autoencoder
state_ae, state_ae_history = train_state_autoencoder(
    file_name   = "state_encoder_overfit_v2.pt",
    linklengths = LINK_LENGTHS,
    dof         = 3,
    latent_dim  = 64,
    N           = 240_000,
    batch_size  = 128,
    epochs      = 8000,
    lr          = 1e-3,
    log_every   = 100,
    device      = device,
    save_path   = "data/state_autoencoder_overfit_v2.pt"
)

print("Weights saved in 'data/state_autoencoder_overfit_v2.pt'")
# Out:
# Training State Autoencoder:   0%|          | 0/8000 [00:00<?, ?it/s]
# Test loss: 0.000606
# Saved: data/state_autoencoder_overfit_v2.pt  (encoder -> data\state_encoder_overfit_v2.pt)
# Weights saved in 'data/state_autoencoder_overfit_v2.pt'

# %%
# ---------- Datasets generation ----------
SEED = 42

# General Dataset
dataset_overfit_v2_general = generate_dataset(
        N_envs            = 1000,
        pairs_per_env     = 10,
        robot             = robot,
        sphere_rad        = SPHERE_RAD,
        q_min             = Q_MIN,
        q_max             = Q_MAX,
        n_obstacles_range = (1, 3),
        r_range           = (0.06, 0.18),
        workspace_radius  = WORKSPACE_RADIUS,
        dist_from_origin  = (0.5, WORKSPACE_RADIUS),
        require_nontrivial= True,
        grid_length       = GRID_LENGTH,
        n_vox             = N_VOX,
        seed              = SEED,
        save_path         = "data/dataset_overfit_v2_general.pt",
        split             = (0.7, 0.15, 0.15)
        )

# 1 sample Dataset
dataset_overfit_v2_1_sample = generate_dataset(
            N_envs            = 1,
            pairs_per_env     = 1,
            robot             = robot,
            sphere_rad        = SPHERE_RAD,
            q_min             = Q_MIN,
            q_max             = Q_MAX,
            n_obstacles_range = (1, 1),
            r_range           = (0.1, 0.18),
            workspace_radius  = WORKSPACE_RADIUS,
            dist_from_origin  = (0.5, WORKSPACE_RADIUS),
            require_nontrivial= True,
            grid_length       = GRID_LENGTH,
            n_vox             = N_VOX,
            seed              = 6,
            save_path         = "data/dataset_overfit_v2_1_sample.pt"
        )

# 10 samples Dataset
dataset_overfit_v2_10_samples = generate_dataset(
            N_envs            = 1,
            pairs_per_env     = 10,
            robot             = robot,
            sphere_rad        = SPHERE_RAD,
            q_min             = Q_MIN,
            q_max             = Q_MAX,
            n_obstacles_range = (1, 1),
            r_range           = (0.1, 0.18),
            workspace_radius  = WORKSPACE_RADIUS,
            dist_from_origin  = (0.5, WORKSPACE_RADIUS),
            require_nontrivial= True,
            grid_length       = GRID_LENGTH,
            n_vox             = N_VOX,
            seed              = 6,
            save_path         = "data/dataset_overfit_v2_10_samples.pt"
        )

# 640 samples Dataset
dataset_overfit_v2_640_samples = generate_dataset(
            N_envs            = 64,
            pairs_per_env     = 10,
            robot             = robot,
            sphere_rad        = SPHERE_RAD,
            q_min             = Q_MIN,
            q_max             = Q_MAX,
            n_obstacles_range = (1, 2),
            r_range           = (0.06, 0.18),
            workspace_radius  = WORKSPACE_RADIUS,
            dist_from_origin = (0.4, WORKSPACE_RADIUS),
            require_nontrivial= True,
            grid_length       = GRID_LENGTH,
            n_vox             = N_VOX,
            seed              = 6,
            save_path         = "data/dataset_overfit_v2_640_samples.pt"
        )
    
# 5000 samples Dataset
dataset_overfit_v2_5000_samples = generate_dataset(
            N_envs            = 500,
            pairs_per_env     = 10,
            robot             = robot,
            sphere_rad        = SPHERE_RAD,
            q_min             = Q_MIN,
            q_max             = Q_MAX,
            n_obstacles_range = (1, 2),
            r_range           = (0.06, 0.18),
            workspace_radius  = WORKSPACE_RADIUS,
            dist_from_origin = (0.4, WORKSPACE_RADIUS),
            require_nontrivial= True,
            grid_length       = GRID_LENGTH,
            n_vox             = N_VOX,
            seed              = 6,
            save_path         = "data/dataset_overfit_v2_5000_samples.pt",
            split=(0.7, 0.15, 0.15)
        )
# Out:
# Generating dataset:   0%|          | 0/1000 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           10000
#   No valid pair:      9
#   Successful samples: 9991  (99.9%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_overfit_v2_general_train.pt  (6993 samples, 458.8 MB)
#   Saved: data/dataset_overfit_v2_general_val.pt  (1498 samples, 98.3 MB)
#   Saved: data/dataset_overfit_v2_general_test.pt  (1500 samples, 98.4 MB)
# Generating dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           1
#   No valid pair:      0
#   Successful samples: 1  (100.0%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_overfit_v2_1_sample.pt  (0.1 MB)
# Generating dataset:   0%|          | 0/1 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           10
#   No valid pair:      0
#   Successful samples: 10  (100.0%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_overfit_v2_10_samples.pt  (0.7 MB)
# Generating dataset:   0%|          | 0/64 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           640
#   No valid pair:      3
#   Successful samples: 637  (99.5%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_overfit_v2_640_samples.pt  (41.8 MB)
# Generating dataset:   0%|          | 0/500 [00:00<?, ?it/s]
# ────────────────────────────────────────────────
#   Attempts:           5000
#   No valid pair:      6
#   Successful samples: 4994  (99.9%)
# ────────────────────────────────────────────────
#   Saved: data/dataset_overfit_v2_5000_samples_train.pt  (3495 samples, 229.2 MB)
#   Saved: data/dataset_overfit_v2_5000_samples_val.pt  (749 samples, 49.1 MB)
#   Saved: data/dataset_overfit_v2_5000_samples_test.pt  (750 samples, 49.2 MB)

# %%
# ---------- Datasets analysis ----------
print("=== DATASETS - GENERAL STATISTICS ===")

print("\n1. General Dataset:")
print_dataset_stats("data/dataset_overfit_v2_general_train.pt")

print("\n" + "─"*50)
print("2. 1 sample Dataset:")
print_dataset_stats("data/dataset_overfit_v2_1_sample.pt")

print("\n" + "─"*50)
print("3. 10 samples Dataset:")
print_dataset_stats("data/dataset_overfit_v2_10_samples.pt")

print("\n" + "─"*50)
print("4. 640 samples Dataset:")
print_dataset_stats("data/dataset_overfit_v2_640_samples.pt")

print("\n" + "─"*50)
print("5. 5000 samples Dataset:")
print_dataset_stats("data/dataset_overfit_v2_5000_samples_train.pt")

print("\n" + "="*20 + " INTERACTIVE VISUALIZATION " + "="*20 + "\n")
interactive_dataset = torch.load("data/dataset_overfit_v2_10_samples.pt", weights_only=False)
browse_dataset(interactive_dataset, grid_length=GRID_LENGTH)
# Out:
# === DATASETS - GENERAL STATISTICS ===
#
# 1. General Dataset:
# Dataset: 6993 samples
#   sdf          (6993, 1, 128, 128)
#   q_start      (6993, 3)
#   q_goal       (6993, 3)
#   obstacles    (6993, 3, 3)
#   n_obstacles  (6993,)
#
# Metadata: {'N': 6993, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [0.35, 0.45, 0.2], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 100 samples): mean=0.000  (should be ~0.0)
#
# ──────────────────────────────────────────────────
# 2. 1 sample Dataset:
# Dataset: 1 samples
#   sdf          (1, 1, 128, 128)
#   q_start      (1, 3)
#   q_goal       (1, 3)
#   obstacles    (1, 1, 3)
#   n_obstacles  (1,)
#
# Metadata: {'N': 1, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [0.35, 0.45, 0.2], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 1 samples): mean=0.000  (should be ~0.0)
#
# ──────────────────────────────────────────────────
# 3. 10 samples Dataset:
# Dataset: 10 samples
#   sdf          (10, 1, 128, 128)
#   q_start      (10, 3)
#   q_goal       (10, 3)
#   obstacles    (10, 1, 3)
#   n_obstacles  (10,)
#
# Metadata: {'N': 10, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [0.35, 0.45, 0.2], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 10 samples): mean=0.000  (should be ~0.0)
#
# ──────────────────────────────────────────────────
# 4. 640 samples Dataset:
# Dataset: 637 samples
#   sdf          (637, 1, 128, 128)
#   q_start      (637, 3)
#   q_goal       (637, 3)
#   obstacles    (637, 2, 3)
#   n_obstacles  (637,)
#
# Metadata: {'N': 637, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [0.35, 0.45, 0.2], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 100 samples): mean=0.000  (should be ~0.0)
#
# ──────────────────────────────────────────────────
# 5. 5000 samples Dataset:
# Dataset: 3495 samples
#   sdf          (3495, 1, 128, 128)
#   q_start      (3495, 3)
#   q_goal       (3495, 3)
#   obstacles    (3495, 2, 3)
#   n_obstacles  (3495,)
#
# Metadata: {'N': 3495, 'grid_length': 2.5, 'n_vox': 128, 'dof': 3, 'linklengths': [0.35, 0.45, 0.2], 'sphere_rad': 0.08, 'q_min': [-2.827433388230814, -2.827433388230814, -2.827433388230814], 'q_max': [2.827433388230814, 2.827433388230814, 2.827433388230814]}
#
# Start-config collision rate (first 100 samples): mean=0.000  (should be ~0.0)
#
# ==================== INTERACTIVE VISUALIZATION ====================
# VBox(children=(HBox(children=(Button(description='◄ Prev', layout=Layout(width='100px'), style=ButtonStyle()),…

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Overfitting: 1 sample verification
print("Starting training...")
    
model_1_sample, history_1_sample = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_1_sample.pt",
    val_dataset         = None,
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_overfit_v2.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 1,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_overfit__v2_1_sample.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_overfit_v2.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           0.0539   1500.0000     80.8513
# joints         0.0000      5.0000      0.0000
# smooth         0.2078      2.0000      0.4157
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=257.1568  coll=229.3217  joints=0.0000  smooth=27.6550  spacing=0.1800  explore=0.0000
# Epoch   400 | lr=4.09e-04 | train=160.6572  coll=104.8042  joints=0.0609  smooth=54.1401  spacing=1.6519  explore=0.0000
# Epoch   600 | lr=3.70e-04 | train=153.0728  coll=104.4255  joints=0.0981  smooth=47.1659  spacing=1.3832  explore=0.0000
# Epoch   800 | lr=3.35e-04 | train=153.1893  coll=97.5544  joints=0.4049  smooth=53.6816  spacing=1.5484  explore=0.0000
# Epoch  1000 | lr=3.03e-04 | train=121.2564  coll=76.4040  joints=0.5251  smooth=43.2606  spacing=1.0667  explore=0.0000
# Epoch  1200 | lr=2.74e-04 | train=101.2181  coll=71.8919  joints=0.0810  smooth=28.7179  spacing=0.5273  explore=0.0000
# Epoch  1400 | lr=2.48e-04 | train=39.9738  coll=33.6749  joints=0.0000  smooth=6.1377  spacing=0.1612  explore=0.0000
# Epoch  1600 | lr=2.25e-04 | train=38.5407  coll=33.9445  joints=0.0000  smooth=4.4187  spacing=0.1774  explore=0.0000
# Epoch  1800 | lr=2.03e-04 | train=38.4317  coll=33.9910  joints=0.0000  smooth=4.2582  spacing=0.1826  explore=0.0000
# Epoch  2000 | lr=1.84e-04 | train=38.3987  coll=34.0617  joints=0.0000  smooth=4.1582  spacing=0.1788  explore=0.0000
# Epoch  2200 | lr=1.66e-04 | train=38.6905  coll=34.1861  joints=0.0000  smooth=4.3221  spacing=0.1823  explore=0.0000
# Epoch  2400 | lr=1.51e-04 | train=38.4552  coll=34.1334  joints=0.0000  smooth=4.1419  spacing=0.1798  explore=0.0000
# Epoch  2600 | lr=1.36e-04 | train=38.1424  coll=34.1100  joints=0.0000  smooth=3.8626  spacing=0.1698  explore=0.0000
# Epoch  2800 | lr=1.23e-04 | train=38.2569  coll=34.1343  joints=0.0000  smooth=3.9634  spacing=0.1592  explore=0.0000
# Epoch  3000 | lr=1.12e-04 | train=38.3100  coll=34.1343  joints=0.0000  smooth=4.0144  spacing=0.1613  explore=0.0000
# Epoch  3200 | lr=1.01e-04 | train=37.9880  coll=34.1068  joints=0.0000  smooth=3.7295  spacing=0.1518  explore=0.0000
# Epoch  3400 | lr=9.13e-05 | train=38.2535  coll=34.1164  joints=0.0000  smooth=3.9669  spacing=0.1702  explore=0.0000
# Epoch  3600 | lr=8.26e-05 | train=38.0914  coll=34.2738  joints=0.0000  smooth=3.6594  spacing=0.1581  explore=0.0000
# Epoch  3800 | lr=7.47e-05 | train=38.0222  coll=34.1015  joints=0.0000  smooth=3.7630  spacing=0.1577  explore=0.0000
# Epoch  4000 | lr=6.76e-05 | train=38.2070  coll=34.1435  joints=0.0000  smooth=3.9030  spacing=0.1605  explore=0.0000
# Model saved: models/warm_start_planner_overfit__v2_1_sample.pt

# %%
# ---------- Trajectory Visualization ----------
print("Loading model and dataset...")

# Load the model
model_1_sample = torch.load("models/warm_start_planner_overfit__v2_1_sample.pt", weights_only=False)
    
# Launch the visualizator
browse_trajectories(
    model     = model_1_sample,
    dataset   = "data/dataset_overfit_v2_1_sample.pt",
    save_name = "overfit_1_sample_working"
)
# Out:
# Loading model and dataset...
# VBox(children=(HBox(children=(Button(description='◄ Prev', layout=Layout(width='100px'), style=ButtonStyle()),…

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Overfitting: 10 samples verification
print("Starting training...")
    
model_10_samples, history_10_samples = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_10_samples.pt",
    val_dataset         = None,
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_overfit_v2.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 10,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_overfit__v2_10_samples.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_overfit_v2.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           0.5353   1500.0000    802.8797
# joints         0.0000      5.0000      0.0000
# smooth         0.3151      2.0000      0.6302
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=120.1417  coll=114.9090  joints=0.0000  smooth=5.1264  spacing=0.1063  explore=0.0000
# Epoch   400 | lr=4.09e-04 | train=116.1176  coll=112.6766  joints=0.0000  smooth=3.3792  spacing=0.0619  explore=0.0000
# Epoch   600 | lr=3.70e-04 | train=113.8487  coll=111.0468  joints=0.0000  smooth=2.7571  spacing=0.0449  explore=0.0000
# Epoch   800 | lr=3.35e-04 | train=113.2970  coll=110.6120  joints=0.0000  smooth=2.6445  spacing=0.0405  explore=0.0000
# Epoch  1000 | lr=3.03e-04 | train=112.7031  coll=110.1584  joints=0.0000  smooth=2.5090  spacing=0.0358  explore=0.0000
# Epoch  1200 | lr=2.74e-04 | train=113.2579  coll=110.8952  joints=0.0000  smooth=2.3286  spacing=0.0341  explore=0.0000
# Epoch  1400 | lr=2.48e-04 | train=112.5965  coll=110.2591  joints=0.0000  smooth=2.3036  spacing=0.0338  explore=0.0000
# Epoch  1600 | lr=2.25e-04 | train=112.4810  coll=110.1219  joints=0.0000  smooth=2.3255  spacing=0.0336  explore=0.0000
# Epoch  1800 | lr=2.03e-04 | train=112.3661  coll=110.0992  joints=0.0000  smooth=2.2349  spacing=0.0321  explore=0.0000
# Epoch  2000 | lr=1.84e-04 | train=112.0632  coll=109.9102  joints=0.0000  smooth=2.1217  spacing=0.0313  explore=0.0000
# Epoch  2200 | lr=1.66e-04 | train=112.2475  coll=110.0613  joints=0.0000  smooth=2.1572  spacing=0.0290  explore=0.0000
# Epoch  2400 | lr=1.51e-04 | train=112.0424  coll=109.9285  joints=0.0000  smooth=2.0849  spacing=0.0290  explore=0.0000
# Epoch  2600 | lr=1.36e-04 | train=111.8811  coll=109.8049  joints=0.0000  smooth=2.0485  spacing=0.0276  explore=0.0000
# Epoch  2800 | lr=1.23e-04 | train=111.8774  coll=109.7889  joints=0.0000  smooth=2.0612  spacing=0.0273  explore=0.0000
# Epoch  3000 | lr=1.12e-04 | train=111.8044  coll=109.7363  joints=0.0000  smooth=2.0408  spacing=0.0274  explore=0.0000
# Epoch  3200 | lr=1.01e-04 | train=111.6686  coll=109.6469  joints=0.0000  smooth=1.9950  spacing=0.0268  explore=0.0000
# Epoch  3400 | lr=9.13e-05 | train=111.7206  coll=109.6919  joints=0.0000  smooth=2.0008  spacing=0.0279  explore=0.0000
# Epoch  3600 | lr=8.26e-05 | train=111.6581  coll=109.6070  joints=0.0000  smooth=2.0224  spacing=0.0287  explore=0.0000
# Epoch  3800 | lr=7.47e-05 | train=111.5687  coll=109.5525  joints=0.0000  smooth=1.9884  spacing=0.0277  explore=0.0000
# Epoch  4000 | lr=6.76e-05 | train=111.8105  coll=109.7773  joints=0.0000  smooth=2.0053  spacing=0.0279  explore=0.0000
# Model saved: models/warm_start_planner_overfit__v2_10_samples.pt

# %%
# ---------- Trajectory Visualization ----------
print("Loading model and dataset...")

# Load the model
model_10_samples = torch.load("models/warm_start_planner_overfit__v2_10_samples.pt", weights_only=False)
    
# Launch the visualizator
browse_trajectories(
    model     = model_10_samples,
    dataset   = "data/dataset_overfit_v2_10_samples.pt",
    save_name = "overfit_10_samples_working"
)
# Out:
# Loading model and dataset...
# VBox(children=(HBox(children=(Button(description='◄ Prev', layout=Layout(width='100px'), style=ButtonStyle()),…

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset
print("Starting training...")
    
model_general, history_general = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_general_train.pt",
    val_dataset         = "data/dataset_overfit_v2_general_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_overfit_v2.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 128,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_general_v1.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_overfit_v2.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll           7.5295   1500.0000  11294.3223
# joints         0.0000      5.0000      0.0000
# smooth         0.2750      2.0000      0.5500
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=210.2817  coll=198.7995  joints=6.8560  smooth=4.2959  spacing=0.3303  explore=0.0000  val=288.4116
# Epoch   400 | lr=4.09e-04 | train=152.1315  coll=143.9646  joints=1.7593  smooth=5.6916  spacing=0.7161  explore=0.0000  val=172.1064
# Epoch   600 | lr=3.70e-04 | train=130.0565  coll=120.2969  joints=1.9338  smooth=6.8271  spacing=0.9988  explore=0.0000  val=135.6005
# Epoch   800 | lr=3.35e-04 | train=124.8601  coll=118.9156  joints=0.1853  smooth=5.0555  spacing=0.7038  explore=0.0000  val=110.2411
# Epoch  1000 | lr=3.03e-04 | train=105.6427  coll=99.5436  joints=0.4359  smooth=4.9387  spacing=0.7245  explore=0.0000  val=109.0384
# Epoch  1200 | lr=2.74e-04 | train=111.2228  coll=105.6637  joints=0.2971  smooth=4.6172  spacing=0.6447  explore=0.0000  val=106.3211
# Epoch  1400 | lr=2.48e-04 | train=88.4021  coll=83.3539  joints=0.2299  smooth=4.2670  spacing=0.5514  explore=0.0000  val=104.2006
# Epoch  1600 | lr=2.25e-04 | train=94.5731  coll=90.1413  joints=0.0440  smooth=3.8723  spacing=0.5156  explore=0.0000  val=101.8820
# Epoch  1800 | lr=2.03e-04 | train=93.3791  coll=88.3032  joints=0.2837  smooth=4.3030  spacing=0.4892  explore=0.0000  val=100.2530
# Epoch  2000 | lr=1.84e-04 | train=91.8109  coll=87.4279  joints=0.2222  smooth=3.7404  spacing=0.4203  explore=0.0000  val=100.6222
# Epoch  2200 | lr=1.66e-04 | train=91.6534  coll=87.2267  joints=0.0988  smooth=3.9164  spacing=0.4116  explore=0.0000  val=100.0933
# Epoch  2400 | lr=1.51e-04 | train=101.5243  coll=97.1316  joints=0.0971  smooth=3.8805  spacing=0.4151  explore=0.0000  val=99.4165
# Epoch  2600 | lr=1.36e-04 | train=95.9712  coll=91.7465  joints=0.2050  smooth=3.6437  spacing=0.3759  explore=0.0000  val=98.4512
# Epoch  2800 | lr=1.23e-04 | train=105.5154  coll=101.0824  joints=0.1659  smooth=3.8422  spacing=0.4249  explore=0.0000  val=99.0748
# Epoch  3000 | lr=1.12e-04 | train=97.0157  coll=92.7858  joints=0.1861  smooth=3.6536  spacing=0.3902  explore=0.0000  val=97.7730
# Epoch  3200 | lr=1.01e-04 | train=95.2093  coll=91.0940  joints=0.1101  smooth=3.6581  spacing=0.3471  explore=0.0000  val=97.9207
# Epoch  3400 | lr=9.13e-05 | train=90.2609  coll=85.7443  joints=0.4799  smooth=3.6552  spacing=0.3816  explore=0.0000  val=97.9109
# Epoch  3600 | lr=8.26e-05 | train=96.3661  coll=92.1459  joints=0.0857  smooth=3.7863  spacing=0.3482  explore=0.0000  val=97.6114
# Epoch  3800 | lr=7.47e-05 | train=94.5400  coll=90.3970  joints=0.0920  smooth=3.6706  spacing=0.3803  explore=0.0000  val=97.0772
# Epoch  4000 | lr=6.76e-05 | train=89.5882  coll=85.3315  joints=0.1218  smooth=3.7527  spacing=0.3822  explore=0.0000  val=97.1925
# Model saved: models/warm_start_planner_general_v1.pt

# %%
# ---------- WarmStartPlanner SSL Training ----------
# Full dataset
print("Starting training...")
    
model_general_v2, history_general_v2 = train(
    # Paths
    train_dataset       = "data/dataset_overfit_v2_general_train.pt",
    val_dataset         = "data/dataset_overfit_v2_general_val.pt",
        
    # Configuration
    T                   = 50,
    C                   = 10,
        
    # Pre-trained encoders
    env_encoder_path    = "data/env_encoder_overfit_v2.pt",
    state_encoder_path  = "data/state_encoder_overfit_v2.pt",
    freeze_encoders     = False,
        
    # Parameters
    n_epochs            = 4000,
    batch_size          = 256,
    lr                  = 5e-4,
        
    # Loss weights
    w_coll              = 1500.0,
    w_joints            = 5.0,
    w_smooth            = 2.0,
    w_spacing           = 1.0,
    w_explore           = 5.0,
        
    # Collision parameters
    explore_threshold   = 0.5,
    collision_eps       = 0.20,
    dt                  = 0.1,
        
    # Monitoring and Hardware
    log_every           = 200,
    device              = "cuda",
    save_path           = "models/warm_start_planner_general_v2.pt",
)
# Out:
# Starting training...
# Loaded env encoder:   data/env_encoder_overfit_v2.pt
# Loaded state encoder: data/state_encoder_overfit_v2.pt
#
# Loss              Raw      Weight    Weighted
# ──────────────────────────────────────────────
# coll          14.7539   1500.0000  22130.8022
# joints         0.0000      5.0000      0.0000
# smooth         0.2816      2.0000      0.5632
# spacing        0.0000      1.0000      0.0000
# explore        0.5000      5.0000      2.5000
# Training:   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch   200 | lr=4.52e-04 | train=178.3258  coll=172.5755  joints=1.4609  smooth=4.0302  spacing=0.2438  explore=0.0154  val=180.7327
# Epoch   400 | lr=4.09e-04 | train=115.3756  coll=110.2159  joints=1.2775  smooth=3.6337  spacing=0.2485  explore=0.0000  val=113.3982
# Epoch   600 | lr=3.70e-04 | train=104.9051  coll=100.8909  joints=0.2982  smooth=3.5002  spacing=0.2158  explore=0.0000  val=98.8827
# Epoch   800 | lr=3.35e-04 | train=95.5725  coll=91.8111  joints=0.0143  smooth=3.5393  spacing=0.2078  explore=0.0000  val=94.4493
# Epoch  1000 | lr=3.03e-04 | train=96.2324  coll=92.3820  joints=0.0294  smooth=3.6098  spacing=0.2112  explore=0.0000  val=93.4150
# Epoch  1200 | lr=2.74e-04 | train=97.8107  coll=94.3036  joints=0.0179  smooth=3.3076  spacing=0.1816  explore=0.0000  val=94.5574
# Epoch  1400 | lr=2.48e-04 | train=93.8781  coll=90.2121  joints=0.0056  smooth=3.4740  spacing=0.1865  explore=0.0000  val=91.9222
# Epoch  1600 | lr=2.25e-04 | train=92.2862  coll=88.5205  joints=0.0069  smooth=3.5746  spacing=0.1842  explore=0.0000  val=91.3511
# Epoch  1800 | lr=2.03e-04 | train=92.0865  coll=88.3160  joints=0.0029  smooth=3.5902  spacing=0.1773  explore=0.0000  val=92.0052
# Epoch  2000 | lr=1.84e-04 | train=93.0875  coll=89.4360  joints=0.0127  smooth=3.4780  spacing=0.1607  explore=0.0000  val=91.6957
# Epoch  2200 | lr=1.66e-04 | train=90.2081  coll=86.5672  joints=0.0168  smooth=3.4594  spacing=0.1647  explore=0.0000  val=91.1123
# Epoch  2400 | lr=1.51e-04 | train=86.0897  coll=82.6033  joints=0.0086  smooth=3.3364  spacing=0.1414  explore=0.0000  val=91.1378
# Epoch  2600 | lr=1.36e-04 | train=96.4642  coll=92.6031  joints=0.0549  smooth=3.6500  spacing=0.1562  explore=0.0000  val=91.0358
# Epoch  2800 | lr=1.23e-04 | train=90.4582  coll=86.8509  joints=0.0472  smooth=3.4107  spacing=0.1494  explore=0.0000  val=90.4451
# Epoch  3000 | lr=1.12e-04 | train=85.4354  coll=81.8248  joints=0.0220  smooth=3.4460  spacing=0.1426  explore=0.0000  val=90.5074
# Epoch  3200 | lr=1.01e-04 | train=93.0342  coll=89.4657  joints=0.0101  smooth=3.4130  spacing=0.1453  explore=0.0000  val=90.6928
# Epoch  3400 | lr=9.13e-05 | train=90.8788  coll=87.3115  joints=0.0161  smooth=3.4033  spacing=0.1479  explore=0.0000  val=90.5948
# Epoch  3600 | lr=8.26e-05 | train=85.4765  coll=81.8952  joints=0.0314  smooth=3.3930  spacing=0.1569  explore=0.0000  val=90.5017
# Epoch  3800 | lr=7.47e-05 | train=91.8708  coll=88.3747  joints=0.0003  smooth=3.3523  spacing=0.1434  explore=0.0000  val=90.4706
# Epoch  4000 | lr=6.76e-05 | train=83.0206  coll=79.6440  joints=0.0030  smooth=3.2326  spacing=0.1410  explore=0.0000  val=90.3835
# Model saved: models/warm_start_planner_general_v2.pt

# %%
# ---------- Trajectory Visualization ----------
print("Loading model and dataset...")

# Load the model
model_general = torch.load("models/warm_start_planner_general_v2.pt", weights_only=False)
    
# Launch the visualizator
browse_trajectories(
    model     = model_general,
    dataset   = "data/dataset_overfit_v2_general_test.pt",
    save_name = "general_working_v2"
)
# Out:
# Loading model and dataset...
# VBox(children=(HBox(children=(Button(description='◄ Prev', layout=Layout(width='100px'), style=ButtonStyle()),…
